# %% [markdown]
# ### Задание 2

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
# %config inlinebackend.figure_format = 'svg'

# %% [markdown]
# С помощью функции linspace из библиотеки Numpy создайте массив t из 51 числа от 0 до 10 включительно.

# %%
t = np.linspace(0, 10, 51)
t
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %% [markdown]
# Создайте массив Numpy под названием f, содержащий косинусы элементов массива t.

# %%
f = np.cos(t)
f
# Out:
# array([ 1.        ,  0.98006658,  0.92106099,  0.82533561,  0.69670671,
#         0.54030231,  0.36235775,  0.16996714, -0.02919952, -0.22720209,
#        -0.41614684, -0.58850112, -0.73739372, -0.85688875, -0.94222234,
#        -0.9899925 , -0.99829478, -0.96679819, -0.89675842, -0.79096771,
#        -0.65364362, -0.49026082, -0.30733287, -0.11215253,  0.08749898,
#         0.28366219,  0.46851667,  0.63469288,  0.77556588,  0.88551952,
#         0.96017029,  0.9965421 ,  0.99318492,  0.95023259,  0.86939749,
#         0.75390225,  0.60835131,  0.43854733,  0.25125984,  0.05395542,
#        -0.14550003, -0.33915486, -0.51928865, -0.67872005, -0.81109301,
#        -0.91113026, -0.97484362, -0.99969304, -0.98468786, -0.93042627,
#        -0.83907153])

# %% [markdown]
# Постройте линейную диаграмму, используя массив t для координат по горизонтали,а массив f - для координат по вертикали. Линия графика должна быть зеленого цвета.

# %%
plt.plot(t, f, color = 'green')

# %% [markdown]
# Выведите название диаграммы - 'График f(t)'. Также добавьте названия для горизонтальной оси - 'Значения t' и для вертикальной - 'Значения f'.

# %%
dict_title = {'family': 'Comic Sans MS', 'color': 'orange', 'fontsize': 30}
dict_xlabel = {'family': 'Comic Sans MS', 'color': 'blue', 'fontsize': 20}
dict_ylabel = {'family': 'Comic Sans MS', 'color': 'red', 'fontsize': 20}

# %%
plt.plot(t, f, color = 'green')
plt.title('График f(t)', fontdict = dict_title)
plt.xlabel('Значения t', fontdict = dict_xlabel)
plt.ylabel('Значения f', fontdict = dict_ylabel)
# Out:
# Text(0, 0.5, 'Значения f')

# %% [markdown]
# Ограничьте график по оси x значениями 0.5 и 9.5, а по оси y - значениями -2.5 и 2.5.

# %%
plt.plot(t, f, color = 'green')
plt.title('График f(t)', fontdict = dict_title)
plt.xlabel('Значения t', fontdict = dict_xlabel)
plt.ylabel('Значения f', fontdict = dict_ylabel)
plt.axis([0.5, 9.5, -2.5, 2.5])
# Out:
# (0.5, 9.5, -2.5, 2.5)
